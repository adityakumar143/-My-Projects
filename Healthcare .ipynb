# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('healthcare_dataset.csv')

# %%
df
# Out:
#                       Name  Age  Gender Blood Type Medical Condition  \
# 0          Tiffany Ramirez   81  Female         O-          Diabetes
# 1              Ruben Burns   35    Male         O+            Asthma
# 2                Chad Byrd   61    Male         B-           Obesity
# 3        Antonio Frederick   49    Male         B-            Asthma
# 4      Mrs. Brandy Flowers   51    Male         O-         Arthritis
# ...                    ...  ...     ...        ...               ...
# 9995            James Hood   83    Male         A+           Obesity
# 9996       Stephanie Evans   47  Female        AB+         Arthritis
# 9997  Christopher Martinez   54    Male         B-         Arthritis
# 9998           Amanda Duke   84    Male         A+         Arthritis
# 9999             Eric King   20    Male         B-         Arthritis
#
#      Date of Admission             Doctor                   Hospital  \
# ...

# %%
df.shape
# Out:
# (10000, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                10000 non-null  object
#  1   Age                 10000 non-null  int64
#  2   Gender              10000 non-null  object
#  3   Blood Type          10000 non-null  object
#  4   Medical Condition   10000 non-null  object
#  5   Date of Admission   10000 non-null  object
#  6   Doctor              10000 non-null  object
#  7   Hospital            10000 non-null  object
#  8   Insurance Provider  10000 non-null  object
#  9   Billing Amount      10000 non-null  float64
#  10  Room Number         10000 non-null  int64
#  11  Admission Type      10000 non-null  object
#  12  Discharge Date      10000 non-null  object
#  13  Medication          10000 non-null  object
#  14  Test Results        10000 non-null  object
# ...

# %%
df.describe()
# Out:
#                 Age  Billing Amount   Room Number
# count  10000.000000    10000.000000  10000.000000
# mean      51.452200    25516.806778    300.082000
# std       19.588974    14067.292709    115.806027
# min       18.000000     1000.180837    101.000000
# 25%       35.000000    13506.523967    199.000000
# 50%       52.000000    25258.112566    299.000000
# 75%       68.000000    37733.913727    400.000000
# max       85.000000    49995.902283    500.000000

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Gender', 'Blood Type', 'Medical Condition',
#        'Date of Admission', 'Doctor', 'Hospital', 'Insurance Provider',
#        'Billing Amount', 'Room Number', 'Admission Type', 'Discharge Date',
#        'Medication', 'Test Results'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Name                  0
# Age                   0
# Gender                0
# Blood Type            0
# Medical Condition     0
# Date of Admission     0
# Doctor                0
# Hospital              0
# Insurance Provider    0
# Billing Amount        0
# Room Number           0
# Admission Type        0
# Discharge Date        0
# Medication            0
# Test Results          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['Age'].value_counts()
# Out:
# 59    175
# 78    174
# 31    172
# 20    169
# 35    169
#      ...
# 34    125
# 47    125
# 85    123
# 22    123
# 45    120
# Name: Age, Length: 68, dtype: int64

# %%
df[ 'Blood Type'].value_counts()
# Out:
# AB-    1275
# AB+    1258
# B-     1252
# O+     1248
# O-     1244
# B+     1244
# A+     1241
# A-     1238
# Name: Blood Type, dtype: int64

# %%
df[  'Medical Condition'].value_counts()
# Out:
# Asthma          1708
# Cancer          1703
# Hypertension    1688
# Arthritis       1650
# Obesity         1628
# Diabetes        1623
# Name: Medical Condition, dtype: int64

# %%
df['Medication'].value_counts()
# Out:
# Penicillin     2079
# Lipitor        2015
# Ibuprofen      1976
# Aspirin        1968
# Paracetamol    1962
# Name: Medication, dtype: int64

# %%
df['Admission Type'].value_counts()
# Out:
# Urgent       3391
# Emergency    3367
# Elective     3242
# Name: Admission Type, dtype: int64

# %%
df['Insurance Provider'].value_counts()
# Out:
# Cigna               2040
# Blue Cross          2032
# Aetna               2025
# UnitedHealthcare    1978
# Medicare            1925
# Name: Insurance Provider, dtype: int64

# %%
df['Hospital'].value_counts()
# Out:
# Smith PLC                        19
# Smith and Sons                   17
# Smith Ltd                        14
# Smith Inc                        14
# Johnson PLC                      13
#                                  ..
# Daniel-Benton                     1
# Franco, Hicks and Anderson        1
# Berry PLC                         1
# Martinez, Johnson and Carlson     1
# Torres, Young and Stewart         1
# Name: Hospital, Length: 8639, dtype: int64

# %%
plt.hist(df['Age'],color='Lightgreen')
plt.xlabel('Age')
plt.ylabel('No. of patient')
plt.title('Age Group')
plt.show()

# %%
plt.hist(df['Billing Amount'],color='red')
plt.xlabel('Amount')
plt.ylabel('No. of patient')
plt.title('Billing Amount')
plt.show()

# %%
hospital_counts = df['Hospital'].value_counts()

top_5_hospitals = hospital_counts.head(5)

plt.figure(figsize=(10, 6))
top_5_hospitals.plot(kind='bar', color='skyblue')
plt.title('The most top 5 hospitals')
plt.xlabel('hospitals')
plt.ylabel('count of patients')
plt.xticks(rotation=45)
plt.tight_layout() 
plt.show()

# %%
# 1. What is the distribution of patient ages?


plt.figure(figsize=(10, 5))
sns.histplot(df['Age'], bins=30, kde=True, color='blue')
plt.title('Distribution of Patient Ages')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %%
bins = [0, 20, 40, 60, 80]
labels = ['0-20', '21-40', '41-60', '61-80']
df['Age Group'] = pd.cut(df['Age'], bins=bins, labels=labels, right=False)

age_group_counts = df['Age Group'].value_counts()

top_5_age_groups = age_group_counts.head(5)

plt.figure(figsize=(10, 6))
top_5_age_groups.plot(kind='bar', color='lightgreen')
plt.title('top 5')
plt.xlabel('ages ')
plt.ylabel('count of patients')
plt.xticks(rotation=45)
plt.tight_layout()  
plt.show()

# %%
ax = sns.countplot(x = 'Gender',data = df)

for bars in ax.containers:
    ax.bar_label(bars)
    
plt.title("Gender Distribution in Dataset")
plt.xlabel("Gender")
plt.ylabel("Count")
plt.show()

# %%
ax = sns.countplot(data = df, x = 'Age Group', hue = 'Gender')

for bars in ax.containers:
    ax.bar_label(bars)

# %%
#3. What are the most common medical conditions?

plt.figure(figsize=(12, 6))
top_conditions = df['Medical Condition'].value_counts().head(10)
sns.barplot(x=top_conditions.index, y=top_conditions.values, palette="viridis")
plt.title("Top 10 Most Common Medical Conditions")
plt.xlabel("Medical Condition")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()

# %%
 #4. How are patients distributed by blood type?
    
    
plt.figure(figsize=(8, 5))
sns.countplot(x=df['Blood Type'], order=df['Blood Type'].value_counts().index, palette="coolwarm")
plt.title("Distribution of Blood Types")
plt.xlabel("Blood Type")
plt.ylabel("Count")
plt.show()

# %%
# 5. What is the distribution of billing amounts?
#Distribution of billing amounts

plt.figure(figsize=(10, 5))
sns.histplot(df['Billing Amount'], bins=30, kde=True, color='red')
plt.title('Distribution of Billing Amounts')
plt.xlabel('Billing Amount ($)')
plt.ylabel('Count')
plt.show()

# %%
# 6.Which hospitals have the highest number of admissions?

plt.figure(figsize=(12, 6))
top_hospitals = df['Hospital'].value_counts().head(10)
sns.barplot(x=top_hospitals.index, y=top_hospitals.values, palette="mako")
plt.title("Top 10 Hospitals with Most Admissions")
plt.xlabel("Hospital")
plt.ylabel("Number of Admissions")
plt.xticks(rotation=45)
plt.show()
